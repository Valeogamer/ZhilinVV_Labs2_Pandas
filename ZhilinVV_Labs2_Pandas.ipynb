# %% [markdown]
# # Импортировали Pandas

# %%
import pandas as pd

# %% [markdown]
# # 1. Выполнить загрузку CSV-файла в память посредством Pandas

# %%
df = pd.read_csv("data.csv", encoding='cp1251') # прочли и присвоили данные из data.csv переменной data

# %%
df # вывели данные
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# ...               ...                          ...
# 1919             4510                   14.01.2022
# 1920             4513                   19.01.2022
# 1921             4514                   20.01.2022
# 1922             4516                   25.01.2022
# 1923             4517                   02.02.2022
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         01.08.2020
# 1                         25.06.2019
# 2                         24.05.2020
# 3                         17.04.2021
# 4                         17.04.2021
# ...                              ...
# 1919                            #Н/Д
# 1920                      19.01.2027
# ...

# %% [markdown]
# При выводе данных заметно, что в header содержит символы \r\n
# Отчего я думаю надо избавиться

# %%
df.columns = df.columns.str.replace('[\n\r]', ' ', regex=True)
df
# Out:
#      №  сертификата Дата  внесения  в реестр Срок  действия  сертификата  \
# 0              17/1               26.07.2002                  01.08.2020
# 1              21/2               25.06.2013                  25.06.2019
# 2              27/1               24.05.2005                  24.05.2020
# 3              32/1               20.04.1996                  17.04.2021
# 4              32/2               20.04.1996                  17.04.2021
# ...             ...                      ...                         ...
# 1919           4510               14.01.2022                        #Н/Д
# 1920           4513               19.01.2022                  19.01.2027
# 1921           4514               20.01.2022                  20.01.2027
# 1922           4516               25.01.2022                  25.01.2027
# 1923           4517               02.02.2022                  02.02.2027
#
#                           Наименование  средства (шифр)  \
# ...

# %% [markdown]
# # 2. Показать список уникальных наименований документов, требованиям которых соответствуют представленные средства защиты информации.

# %%
df['Наименования документов, требованиям которых соответствует средство'].unique()  # Самый простой способ получить список уникальных значений в столбце pandas DataFrame
#— использовать функцию unique() .
# Out:
# array(['Соответствует требованиям документов: Требования к ПСЗ ПЭМИН-2015',
#        'Соответствует требованиям документов: РД СВТ(2)',
#        'Соответствует требованиям документов: ТУ',
#        'Соответствует требованиям документов: РД САЗ ПЭМИН-87',
#        'Соответствует требованиям документов: РД САЗ ПЭМИН-87, ТУ',
#        'Соответствует требованиям документов: Требования к САЗ ПЭМИН-2014(А), Требования к САЗ ПЭМИН-2014(Б)',
#        'Соответствует требованиям документов: НМД ПЭМИН-1998, ТУ',
#        'Соответствует требованиям документов: НМД АРР-2000, ТУ',
#        'Соответствует требованиям документов: НМД АРР-2000',
#        'Соответствует требованиям документов: РД НДВ(3), РД СВТ(4)',
#        'Соответствует требованиям документов: Требования к СДЗ, Профиль защиты СДЗ(платы расширения второго класса защиты. ИТ.СДЗ.ПР2.ПЗ)',
#        'Соответствует требованиям документов: РД НДВ(3)',
#        'Соответствует требованиям документов: ТЗИ НСД СУиК ЯМ-1997(3)',
# ...

# %% [markdown]
# # 3. Отобразить список наименований средств, соответствующих двум любым документам с требованиями по сертификации.

# %% [markdown]
# loc — используется для доступа по строковой метке — т.е. фактически по значению индекса и по названию столбца

# %%
df.loc[(df['Наименования документов, требованиям которых соответствует средство'] == 'Соответствует требованиям документов: РД НДВ(3)') | 
         (df['Наименования документов, требованиям которых соответствует средство'] =='Соответствует требованиям документов: РД МЭ(4)')]['Наименование  средства (шифр)']
# Out:
# 43                            ОС MS Windows NT 4.0 Server
# 102                       программа «Ревизор-2 для Linux»
# 156     программно-аппаратный комплекс «Соболь» УВАЛ.0...
# 158     программа фиксации и контроля исходного состоя...
# 229     комплекс средств защиты информации от несанкци...
#                               ...
# 1261                      межсетевой экран Cisco ASA 55xx
# 1273    комплекс программно-информационных средств «Мо...
# 1335                                      ПК «Аист Визир»
# 1426    комплекс программно-информационных средств «Мо...
# 1458              программное обеспечение «Галактика АММ»
# Name: Наименование  средства (шифр), Length: 150, dtype: object

# %% [markdown]
# # 4. Показать наименования тех средств, которые имеют просроченные сертификаты (намомент выполнения задания)

# %% [markdown]
# Для выполнения данного задания переведу колонку "Информация об окончании срока технической поддержки, полученная от заявителя"
# во временной тип и нужно написать условие которая выведет все что меньше сегоднешней даты.

# %%
df.dtypes # проверяем тип данных
# Out:
# №  сертификата                                                                  object
# Дата  внесения  в реестр                                                        object
# Срок  действия  сертификата                                                     object
# Наименование  средства (шифр)                                                   object
# Наименования документов, требованиям которых соответствует средство             object
# Схема  сертификации                                                             object
# Испытательная  лаборатория                                                      object
# Орган по  сертификации                                                          object
# Заявитель                                                                       object
# Реквизиты заявителя  (индекс, адрес, телефон)                                   object
# Информация об окончании срока технической поддержки, полученная от заявителя    object
# dtype: object

# %% [markdown]
# С целью не портить оригинальные данные делаю копии

# %%
df_1 = df.copy()
df_1.dropna(axis='rows', inplace=True)
df_1
# Out:
#      №  сертификата Дата  внесения  в реестр Срок  действия  сертификата  \
# 0              17/1               26.07.2002                  01.08.2020
# 3              32/1               20.04.1996                  17.04.2021
# 4              32/2               20.04.1996                  17.04.2021
# 11               66               26.12.1996                  24.01.2021
# 22           153/12               29.12.2011                  29.12.2020
# ...             ...                      ...                         ...
# 1713           4292               02.09.2020                  04.09.2025
# 1742           4324               16.11.2020                  16.11.2025
# 1752           4335               09.12.2020                  09.12.2025
# 1831           4417               10.06.2021                  10.06.2026
# 1884           4472               25.10.2021                  25.10.2026
#
#                           Наименование  средства (шифр)  \
# ...

# %%
df_1['Срок  действия  сертификата'] = df_1['Срок  действия  сертификата'].str.replace('#Н/Д', '01.01.1900')
df_1['Срок  действия  сертификата'] = pd.to_datetime(df_1['Срок  действия  сертификата'], format='%d.%m.%Y')
df
# Out:
#      №  сертификата Дата  внесения  в реестр Срок  действия  сертификата  \
# 0              17/1               26.07.2002                  01.08.2020
# 1              21/2               25.06.2013                  25.06.2019
# 2              27/1               24.05.2005                  24.05.2020
# 3              32/1               20.04.1996                  17.04.2021
# 4              32/2               20.04.1996                  17.04.2021
# ...             ...                      ...                         ...
# 1919           4510               14.01.2022                        #Н/Д
# 1920           4513               19.01.2022                  19.01.2027
# 1921           4514               20.01.2022                  20.01.2027
# 1922           4516               25.01.2022                  25.01.2027
# 1923           4517               02.02.2022                  02.02.2027
#
#                           Наименование  средства (шифр)  \
# ...

# %%
import datetime as dt

# %%
df_1.loc[df_1['Срок  действия  сертификата']<dt.datetime.now()]['Наименование  средства (шифр)']
# Out:
# 0       фильтр сетевой помехоподавляющий ФСПК-100(200)...
# 3       система защиты информации от несанкционированн...
# 4       система защиты информации от несанкционированн...
# 11       устройство активной защиты информации «Волна-4М»
# 22      комплекс СЗИ от НСД «Аккорд 1.95» (модификация...
#                               ...
# 1377    система защиты акустической речевой информации...
# 1378                      персональная ЭВМ Гамма МБ-16-01
# 1384      программный комплекс «РСП-Контроль», версия 2.0
# 1404                         программный комплекс «Аркан»
# 1405    программный комплекс управления конфигурациями...
# Name: Наименование  средства (шифр), Length: 360, dtype: object

# %% [markdown]
# # 5. Показать наименования тех средств, которые имеют просроченные сертификаты, но приэтом обязаны оказывать поддержку (столбец «Информация об окончании срока технической поддержки, полученная от заявителя»).

# %%
df_2 = df.copy()
df_2['Срок  действия  сертификата'] = df_2['Срок  действия  сертификата'].str.replace('#Н/Д', '01.01.1900')
df_2['Срок  действия  сертификата'] = pd.to_datetime(df_2['Срок  действия  сертификата'], format='%d.%m.%Y')

# %%
df_2['Информация об окончании срока технической поддержки, полученная от заявителя'] = df_2['Информация об окончании срока технической поддержки, полученная от заявителя'].str.replace('бессрочно', dt.datetime.now().strftime('%d.%m.%Y'))
df_2['Информация об окончании срока технической поддержки, полученная от заявителя'] = pd.to_datetime(df_2['Информация об окончании срока технической поддержки, полученная от заявителя'], format ='%d.%m.%Y')
df_2.loc[(df_2['Срок  действия  сертификата']<dt.datetime.now()) &
          (df_2['Информация об окончании срока технической поддержки, полученная от заявителя']>=dt.datetime.now())]['Наименование  средства (шифр)'].to_frame()
# Out:
#                           Наименование  средства (шифр)
# 0     фильтр сетевой помехоподавляющий ФСПК-100(200)...
# 3     система защиты информации от несанкционированн...
# 4     система защиты информации от несанкционированн...
# 11     устройство активной защиты информации «Волна-4М»
# 24    фильтр сетевой помехоподавляющий ФСПК-10-220-9...
# ...                                                 ...
# 1376   система виброакустической защиты «Гамма СВАЗ-01»
# 1377  система защиты акустической речевой информации...
# 1378                    персональная ЭВМ Гамма МБ-16-01
# 1384    программный комплекс «РСП-Контроль», версия 2.0
# 1404                       программный комплекс «Аркан»
#
# [182 rows x 1 columns]

# %% [markdown]
# # 6. Показать наименования всех средств, которые проходили испытания в частныхорганизациях (форма организации ООО, ЗАО, ПАО, АО).

# %%
df[(df['Испытательная  лаборатория'].str.contains('ООО'))|
     (df['Испытательная  лаборатория'].str.contains('ЗАО'))|
     (df['Испытательная  лаборатория'].str.contains('ПАО'))|
     (df['Испытательная  лаборатория'].str.contains('АО'))]['Наименование  средства (шифр)'].to_frame()
# Out:
#                           Наименование  средства (шифр)
# 1     программный комплекс защиты информации от НСД ...
# 2                                   устройство «Корунд»
# 5                            система защиты «Гром-ЗИ-4»
# 6                            система защиты «Гром-ЗИ-4»
# 7                           система защиты «Гром-ЗИ-4А»
# ...                                                 ...
# 1919  программное обеспечение «Сервис электронного д...
# 1920   программное обеспечение SAP S/4HANA, версия 1909
# 1921  программное обеспечение SAP Marketing, версия ...
# 1922  программное обеспечение JaCarta Management Sys...
# 1923                     Антивирус VR Protect для Linux
#
# [1661 rows x 1 columns]
